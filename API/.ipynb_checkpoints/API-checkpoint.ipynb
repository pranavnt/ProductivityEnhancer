# %%
from flask import Flask,render_template,url_for,request

# %%
app = Flask(__name__)

# %%
@app.route('/addEvent', methods=['POST'])
def add_event():
    if request.method=="POST":
        event_name = request.form['event_name']
        start_date = request.form['start_date']
        end_date = request.form['end_date']
    pass

# %%
@app.route('/addToDo', methods=['POST'])
def add_todo():
    pass

# %%
@app.route('/addGoal', methods=['POST'])
def add_goal():
    pass

# %%
@app.route('/addGoal', methods=['POST'])
def add_goal():
    pass

# %%
@app.route('/addGoal', methods=['POST'])
def add_goal():
    pass

# %%
# !git add -A

# %%
# !git commit -m "creating API notebook"
# Out:
# [master b6014db] creating API notebook
#  482 files changed, 134 insertions(+), 72 deletions(-)
#  create mode 100644 API/.ipynb_checkpoints/API-checkpoint.ipynb
#  create mode 100644 API/API.ipynb
#  delete mode 100644 semantic/tasks/collections/docs.js
#  rewrite web_app/index.html (82%)
#  rename {semantic => web_app/semantic}/gulpfile.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/behaviors/api.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/behaviors/form.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/behaviors/state.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/behaviors/visibility.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/collections/breadcrumb.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/collections/form.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/collections/grid.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/collections/menu.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/collections/message.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/collections/table.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/button.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/container.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/divider.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/emoji.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/flag.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/header.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/icon.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/image.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/input.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/label.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/list.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/loader.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/placeholder.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/rail.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/reveal.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/segment.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/step.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/elements/text.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/globals/reset.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/globals/site.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/globals/site.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/accordion.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/accordion.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/calendar.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/calendar.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/checkbox.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/checkbox.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/dimmer.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/dimmer.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/dropdown.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/dropdown.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/embed.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/embed.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/modal.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/modal.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/nag.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/nag.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/popup.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/popup.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/progress.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/progress.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/rating.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/rating.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/search.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/search.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/shape.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/shape.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/sidebar.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/sidebar.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/slider.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/slider.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/sticky.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/sticky.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/tab.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/tab.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/toast.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/toast.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/transition.js (100%)
#  rename {semantic => web_app/semantic}/src/definitions/modules/transition.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/views/ad.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/views/card.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/views/comment.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/views/feed.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/views/item.less (100%)
#  rename {semantic => web_app/semantic}/src/definitions/views/statistic.less (100%)
#  rename {semantic => web_app/semantic}/src/semantic.less (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/breadcrumb.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/breadcrumb.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/form.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/form.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/grid.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/grid.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/menu.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/menu.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/message.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/message.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/table.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/collections/table.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/container.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/container.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/divider.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/divider.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/flag.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/flag.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/header.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/header.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/icon.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/icon.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/image.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/image.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/input.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/input.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/label.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/label.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/list.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/list.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/loader.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/loader.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/rail.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/rail.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/reveal.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/reveal.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/segment.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/segment.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/step.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/elements/step.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/globals/reset.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/globals/reset.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/globals/site.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/globals/site.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/accordion.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/accordion.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/chatroom.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/chatroom.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/checkbox.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/checkbox.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/dimmer.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/dimmer.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/dropdown.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/dropdown.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/embed.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/embed.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/modal.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/modal.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/nag.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/nag.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/popup.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/popup.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/progress.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/progress.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/rating.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/rating.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/search.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/search.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/shape.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/shape.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/sidebar.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/sidebar.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/sticky.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/sticky.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/tab.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/tab.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/transition.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/modules/transition.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/views/ad.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/views/ad.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/views/card.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/views/card.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/views/comment.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/views/comment.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/views/feed.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/views/feed.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/views/item.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/views/item.variables (100%)
#  rename {semantic => web_app/semantic}/src/site/views/statistic.overrides (100%)
#  rename {semantic => web_app/semantic}/src/site/views/statistic.variables (100%)
#  rename {semantic => web_app/semantic}/src/theme.config (100%)
#  rename {semantic => web_app/semantic}/src/theme.less (100%)
#  rename {semantic => web_app/semantic}/src/themes/amazon/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/amazon/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/amazon/globals/site.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/assets/fonts/icons.eot (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/assets/fonts/icons.svg (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/assets/fonts/icons.ttf (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/assets/fonts/icons.woff (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/collections/table.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/collections/table.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/elements/icon.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/elements/icon.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/elements/step.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/elements/step.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/globals/reset.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/globals/reset.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/modules/progress.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/modules/progress.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/views/card.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/basic/views/card.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/bookish/elements/header.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/bookish/elements/header.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/bootstrap3/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/bootstrap3/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/collections/form.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/collections/form.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/collections/menu.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/collections/menu.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/elements/header.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/elements/header.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/modules/accordion.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/modules/accordion.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/views/comment.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/chubby/views/comment.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/collections/table.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/collections/table.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/elements/header.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/elements/header.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/modules/progress.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/modules/progress.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/views/card.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/classic/views/card.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/colored/modules/checkbox.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/colored/modules/checkbox.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/brand-icons.eot (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/brand-icons.svg (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/brand-icons.ttf (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/brand-icons.woff (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/brand-icons.woff2 (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/icons.eot (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/icons.svg (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/icons.ttf (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/icons.woff (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/icons.woff2 (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/outline-icons.eot (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/outline-icons.svg (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/outline-icons.ttf (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/outline-icons.woff (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/fonts/outline-icons.woff2 (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/assets/images/flags.png (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/breadcrumb.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/breadcrumb.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/form.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/form.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/grid.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/grid.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/menu.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/menu.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/message.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/message.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/table.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/collections/table.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/container.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/container.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/divider.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/divider.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/emoji.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/emoji.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/flag.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/flag.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/header.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/header.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/icon.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/icon.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/image.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/image.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/input.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/input.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/label.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/label.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/list.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/list.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/loader.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/loader.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/placeholder.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/placeholder.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/rail.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/rail.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/reveal.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/reveal.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/segment.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/segment.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/step.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/step.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/text.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/elements/text.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/globals/colors.less (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/globals/reset.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/globals/reset.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/globals/site.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/globals/site.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/globals/variation.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/accordion.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/accordion.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/calendar.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/calendar.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/chatroom.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/chatroom.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/checkbox.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/checkbox.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/dimmer.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/dimmer.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/dropdown.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/dropdown.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/embed.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/embed.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/modal.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/modal.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/nag.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/nag.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/popup.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/popup.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/progress.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/progress.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/rating.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/rating.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/search.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/search.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/shape.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/shape.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/sidebar.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/sidebar.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/slider.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/slider.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/sticky.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/sticky.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/tab.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/tab.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/toast.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/toast.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/transition.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/modules/transition.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/ad.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/ad.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/card.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/card.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/comment.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/comment.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/feed.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/feed.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/item.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/item.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/statistic.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/default/views/statistic.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/duo/elements/loader.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/duo/elements/loader.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/fixed-width/collections/grid.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/fixed-width/collections/grid.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/fixed-width/modules/modal.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/fixed-width/modules/modal.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/flat/collections/form.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/flat/collections/form.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/flat/globals/site.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/flat/globals/site.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/assets/fonts/octicons-local.ttf (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/assets/fonts/octicons.svg (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/assets/fonts/octicons.ttf (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/assets/fonts/octicons.woff (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/collections/breadcrumb.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/collections/form.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/collections/form.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/collections/grid.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/collections/menu.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/collections/menu.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/collections/message.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/collections/message.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/collections/table.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/header.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/icon.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/icon.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/image.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/input.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/input.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/label.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/label.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/segment.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/segment.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/step.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/elements/step.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/globals/site.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/modules/dropdown.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/modules/dropdown.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/github/modules/popup.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/gmail/collections/message.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/gmail/collections/message.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/instagram/views/card.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/instagram/views/card.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/joypixels/elements/emoji.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/joypixels/elements/emoji.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/assets/fonts/icons.eot (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/assets/fonts/icons.svg (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/assets/fonts/icons.ttf (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/assets/fonts/icons.woff (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/assets/fonts/icons.woff2 (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/collections/menu.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/collections/menu.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/elements/header.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/elements/header.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/elements/icon.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/elements/icon.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/globals/site.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/globals/site.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/modules/dropdown.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/modules/dropdown.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/modules/modal.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/material/modules/modal.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/pulsar/elements/loader.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/pulsar/elements/loader.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/raised/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/raised/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/resetcss/globals/reset.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/resetcss/globals/reset.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/round/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/round/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/rtl/globals/site.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/rtl/globals/site.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/striped/modules/progress.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/striped/modules/progress.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/timeline/views/feed.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/timeline/views/feed.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/twitter/elements/button.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/twitter/elements/button.variables (100%)
#  rename {semantic => web_app/semantic}/src/themes/twitter/elements/emoji.overrides (100%)
#  rename {semantic => web_app/semantic}/src/themes/twitter/elements/emoji.variables (100%)
#  rename {semantic => web_app/semantic}/tasks/README.md (100%)
#  rename {semantic => web_app/semantic}/tasks/admin/components/create.js (100%)
#  rename {semantic => web_app/semantic}/tasks/admin/components/init.js (100%)
#  rename {semantic => web_app/semantic}/tasks/admin/components/update.js (100%)
#  rename {semantic => web_app/semantic}/tasks/admin/distributions/create.js (100%)
#  rename {semantic => web_app/semantic}/tasks/admin/distributions/init.js (100%)
#  rename {semantic => web_app/semantic}/tasks/admin/distributions/update.js (100%)
#  rename {semantic => web_app/semantic}/tasks/admin/publish.js (100%)
#  rename {semantic => web_app/semantic}/tasks/admin/register.js (100%)
#  rename {semantic => web_app/semantic}/tasks/admin/release.js (100%)
#  rename {semantic => web_app/semantic}/tasks/build.js (100%)
#  rename {semantic => web_app/semantic}/tasks/build/assets.js (100%)
#  rename {semantic => web_app/semantic}/tasks/build/css.js (100%)
#  rename {semantic => web_app/semantic}/tasks/build/javascript.js (100%)
#  rename {semantic => web_app/semantic}/tasks/check-install.js (100%)
#  rename {semantic => web_app/semantic}/tasks/clean.js (100%)
#  rename {semantic => web_app/semantic}/tasks/collections/README.md (100%)
#  rename {semantic => web_app/semantic}/tasks/collections/admin.js (100%)
#  rename {semantic => web_app/semantic}/tasks/collections/build.js (100%)
#  create mode 100644 web_app/semantic/tasks/collections/docs.js
#  rename {semantic => web_app/semantic}/tasks/collections/install.js (100%)
#  rename {semantic => web_app/semantic}/tasks/collections/rtl.js (100%)
#  rename {semantic => web_app/semantic}/tasks/collections/various.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/github.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/oauth.example.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/release.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/templates/README.md (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/templates/bower.json (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/templates/component-package.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/templates/composer.json (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/templates/css-package.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/templates/less-package.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/admin/templates/package.json (100%)
#  rename {semantic => web_app/semantic}/tasks/config/defaults.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/docs.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/npm/gulpfile.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/project/config.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/project/install.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/project/release.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/tasks.js (100%)
#  rename {semantic => web_app/semantic}/tasks/config/user.js (100%)
#  rename {semantic => web_app/semantic}/tasks/docs/build.js (100%)
#  rename {semantic => web_app/semantic}/tasks/docs/metadata.js (100%)
#  rename {semantic => web_app/semantic}/tasks/docs/serve.js (100%)
#  rename {semantic => web_app/semantic}/tasks/install.js (100%)
#  rename {semantic => web_app/semantic}/tasks/rtl/build.js (100%)
#  rename {semantic => web_app/semantic}/tasks/rtl/watch.js (100%)
#  rename {semantic => web_app/semantic}/tasks/version.js (100%)
#  rename {semantic => web_app/semantic}/tasks/watch.js (100%)
#  rewrite web_app/website.html (94%)

# %%
# !git push -u origin pranav-dev
